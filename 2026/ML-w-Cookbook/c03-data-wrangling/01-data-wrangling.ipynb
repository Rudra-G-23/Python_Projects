# %% [markdown]
# # 3.1 Creating a Data Frame

# %%
import pandas as pd

# %%
dataframe = pd.DataFrame()

# Add columns
dataframe['Name'] = ['Jacky Jackson', 'Steven Stevenson']
dataframe['Age'] = [38, 25]
dataframe['Driver'] = [True, False]


# Show DataFrame
dataframe
# Out:
#                Name  Age  Driver
# 0     Jacky Jackson   38    True
# 1  Steven Stevenson   25   False

# %%
# Create row
new_person = pd.Series(['Molly Mooney', 40, True], index=['Name','Age','Driver'])
new_person
# Out:
# Name      Molly Mooney
# Age                 40
# Driver            True
# dtype: object

# %%
# Append row
dataframe = pd.concat(
    [dataframe, pd.DataFrame([new_person])],
    ignore_index=True
)

# %%
dataframe
# Out:
#                Name  Age  Driver
# 0     Jacky Jackson   38    True
# 1  Steven Stevenson   25   False
# 2      Molly Mooney   40    True

# %% [markdown]
# # 3.2 Describing the Data

# %%
titanic_data_set_url = "https://raw.githubusercontent.com/chrisalbon/sim_data/refs/heads/main/titanic.csv"

# %%
df = pd.read_csv(titanic_data_set_url)

# %%
df
# Out:
#                                                Name PClass    Age     Sex  \
# 0                      Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                       Allison, Miss Helen Loraine    1st   2.00  female
# 2               Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                     Allison, Master Hudson Trevor    1st   0.92    male
# ...                                             ...    ...    ...     ...
# 1308                             Zakarian, Mr Artun    3rd  27.00    male
# 1309                         Zakarian, Mr Maprieder    3rd  26.00    male
# 1310                               Zenni, Mr Philip    3rd  22.00    male
# 1311                               Lievens, Mr Rene    3rd  24.00    male
# 1312                                 Zimmerman, Leo    3rd  29.00    male
#
#       Survived  SexCode
# 0            1        1
# 1            0        1
# ...

# %%
df.describe()
# Out:
#               Age     Survived      SexCode
# count  756.000000  1313.000000  1313.000000
# mean    30.397989     0.342727     0.351866
# std     14.259049     0.474802     0.477734
# min      0.170000     0.000000     0.000000
# 25%     21.000000     0.000000     0.000000
# 50%     28.000000     0.000000     0.000000
# 75%     39.000000     1.000000     1.000000
# max     71.000000     1.000000     1.000000

# %% [markdown]
# # 3.3 Navigating DataFrames

# %%
df.iloc[:] # all
# Out:
#                                                Name PClass    Age     Sex  \
# 0                      Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                       Allison, Miss Helen Loraine    1st   2.00  female
# 2               Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                     Allison, Master Hudson Trevor    1st   0.92    male
# ...                                             ...    ...    ...     ...
# 1308                             Zakarian, Mr Artun    3rd  27.00    male
# 1309                         Zakarian, Mr Maprieder    3rd  26.00    male
# 1310                               Zenni, Mr Philip    3rd  22.00    male
# 1311                               Lievens, Mr Rene    3rd  24.00    male
# 1312                                 Zimmerman, Leo    3rd  29.00    male
#
#       Survived  SexCode
# 0            1        1
# 1            0        1
# ...

# %%
df.iloc[1: 4]
# Out:
#                                             Name PClass   Age     Sex  \
# 1                    Allison, Miss Helen Loraine    1st   2.0  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.0    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female
#
#    Survived  SexCode
# 1         0        1
# 2         0        0
# 3         0        1

# %%
df.set_index(df['Name']) 
# now if you notice one number col is remove
# see above and below df
# Out:
#                                                                                         Name  \
# Name
# Allen, Miss Elisabeth Walton                                    Allen, Miss Elisabeth Walton
# Allison, Miss Helen Loraine                                      Allison, Miss Helen Loraine
# Allison, Mr Hudson Joshua Creighton                      Allison, Mr Hudson Joshua Creighton
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)  Allison, Mrs Hudson JC (Bessie Waldo Daniels)
# Allison, Master Hudson Trevor                                  Allison, Master Hudson Trevor
# ...                                                                                      ...
# Zakarian, Mr Artun                                                        Zakarian, Mr Artun
# Zakarian, Mr Maprieder                                                Zakarian, Mr Maprieder
# Zenni, Mr Philip                                                            Zenni, Mr Philip
# ...

# %% [markdown]
# # 3.4 Selecting Rows Based on Conditionals

# %%
df[df['Sex'] == 'female'].head(2)
# Out:
#                            Name PClass   Age     Sex  Survived  SexCode
# 0  Allen, Miss Elisabeth Walton    1st  29.0  female         1        1
# 1   Allison, Miss Helen Loraine    1st   2.0  female         0        1

# %%
df[(df['Sex'] == 'female') & (df['Age'] >= 65)]
# Out:
#                                                  Name PClass   Age     Sex  \
# 73  Crosby, Mrs Edward Gifford (Catherine Elizabet...    1st  69.0  female
#
#     Survived  SexCode
# 73         1        1

# %% [markdown]
# # 3.5 Replacing Values

# %%
df['Sex'].replace(['female', 'male'], ['Women', 'Men']).sample(3)
# Out:
# 242      Men
# 969      Men
# 905    Women
# Name: Sex, dtype: str

# %% [markdown]
# # 3.6 Renaming Columns

# %%
df.rename(columns={'PClass': 'Passenger Class', 'Sex': 'Gender'}).sample(3)
# Out:
#                      Name Passenger Class   Age Gender  Survived  SexCode
# 160      Lewy, Mr Ervin G             1st   NaN   male         0        0
# 1279  Vartunian, Mr David             3rd  22.0   male         1        0
# 1106      Pasic, Mr Jakob             3rd   NaN   male         0        0

# %% [markdown]
# # 3.7 Finding the Minimum, Maximum, Sum, Average, and Count

# %%
df = pd.read_csv(titanic_data_set_url)
df
# Out:
#                                                Name PClass    Age     Sex  \
# 0                      Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                       Allison, Miss Helen Loraine    1st   2.00  female
# 2               Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                     Allison, Master Hudson Trevor    1st   0.92    male
# ...                                             ...    ...    ...     ...
# 1308                             Zakarian, Mr Artun    3rd  27.00    male
# 1309                         Zakarian, Mr Maprieder    3rd  26.00    male
# 1310                               Zenni, Mr Philip    3rd  22.00    male
# 1311                               Lievens, Mr Rene    3rd  24.00    male
# 1312                                 Zimmerman, Leo    3rd  29.00    male
#
#       Survived  SexCode
# 0            1        1
# 1            0        1
# ...

# %%
# Calculate statistics
print('Maximum:', df['Age'].max())
print('Minimum:', df['Age'].min())
print('Mean:', df['Age'].mean())
print('Sum:', df['Age'].sum())
print('Count:', df['Age'].count())
# Out:
# Maximum: 71.0
# Minimum: 0.17
# Mean: 30.397989417989418
# Sum: 22980.88
# Count: 756

# %%
df.count()
# Out:
# Name        1313
# PClass      1313
# Age          756
# Sex         1313
# Survived    1313
# SexCode     1313
# dtype: int64

# %% [markdown]
# # 3.8 Finding Unique Values

# %%
df['Sex'].unique()
# Out:
# <StringArray>
# ['female', 'male']
# Length: 2, dtype: str

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      851
# female    462
# Name: count, dtype: int64

# %% [markdown]
# # 3.9 Handling Missing Values

# %%
df[df['Age'].isnull()].sample(3)
# Out:
#                                  Name PClass  Age     Sex  Survived  SexCode
# 1300            Wiseman, Mr Phillippe    3rd  NaN    male         0        0
# 1001                McCoy, Miss Alice    3rd  NaN  female         0        1
# 1036  Moubarek, Master William George    3rd  NaN    male         0        0

# %%
import numpy as np

# %%
df['sex_2'] = df['Sex'].replace('male', np.nan)

# %%
df['sex_2']
# Out:
# 0       female
# 1       female
# 2          NaN
# 3       female
# 4          NaN
#          ...
# 1308       NaN
# 1309       NaN
# 1310       NaN
# 1311       NaN
# 1312       NaN
# Name: sex_2, Length: 1313, dtype: str

# %%
# Load data, set missing values
dataframe = pd.read_csv(titanic_data_set_url, na_values=[np.nan, 'NONE', -999])

# %%
dataframe
# Out:
#                                                Name PClass    Age     Sex  \
# 0                      Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                       Allison, Miss Helen Loraine    1st   2.00  female
# 2               Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                     Allison, Master Hudson Trevor    1st   0.92    male
# ...                                             ...    ...    ...     ...
# 1308                             Zakarian, Mr Artun    3rd  27.00    male
# 1309                         Zakarian, Mr Maprieder    3rd  26.00    male
# 1310                               Zenni, Mr Philip    3rd  22.00    male
# 1311                               Lievens, Mr Rene    3rd  24.00    male
# 1312                                 Zimmerman, Leo    3rd  29.00    male
#
#       Survived  SexCode
# 0            1        1
# 1            0        1
# ...

# %% [markdown]
# # 3.10 Deleting a Column

# %%
df.drop(['Age', 'sex_2'], axis=1).sample(3)
# Out:
#                              Name PClass   Sex  Survived  SexCode
# 1071  Nosworthy, Mr Richard Cater    3rd  male         0        0
# 539              Reeves, Mr David    2nd  male         0        0
# 813          Gallagher, Mr Martin    3rd  male         0        0

# %% [markdown]
# # 3.11 Deleting a Row

# %%
df[df['Name'] != 'Allison, Miss Helen Loraine'].head(2)
# Out:
#                                   Name PClass   Age     Sex  Survived  \
# 0         Allen, Miss Elisabeth Walton    1st  29.0  female         1
# 2  Allison, Mr Hudson Joshua Creighton    1st  30.0    male         0
#
#    SexCode   sex_2
# 0        1  female
# 2        0     NaN

# %% [markdown]
# # 3.12 Dropping Duplicate Rows

# %%
df.drop_duplicates()
# Out:
#                                                Name PClass    Age     Sex  \
# 0                      Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                       Allison, Miss Helen Loraine    1st   2.00  female
# 2               Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                     Allison, Master Hudson Trevor    1st   0.92    male
# ...                                             ...    ...    ...     ...
# 1308                             Zakarian, Mr Artun    3rd  27.00    male
# 1309                         Zakarian, Mr Maprieder    3rd  26.00    male
# 1310                               Zenni, Mr Philip    3rd  22.00    male
# 1311                               Lievens, Mr Rene    3rd  24.00    male
# 1312                                 Zimmerman, Leo    3rd  29.00    male
#
#       Survived  SexCode   sex_2
# 0            1        1  female
# ...

# %% [markdown]
# # 3.13 Grouping Rows by Values

# %%
df.groupby('Sex')['Age'].mean()
# Out:
# Sex
# female    29.396424
# male      31.014338
# Name: Age, dtype: float64

# %%
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.666667
# male      0.166863
# Name: Survived, dtype: float64

# %% [markdown]
# # 3.14 Grouping Rows by Time

# %%
import numpy as np

# %%
time_index = pd.date_range('06/06/2017', periods=100_000, freq='30s')

# %%
df = pd.DataFrame(index=time_index)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df['sale_amount'] = np.random.randint(1, 200, 100_000)

# %%
df
# Out:
#                      sale_amount
# 2017-06-06 00:00:00          128
# 2017-06-06 00:00:30          173
# 2017-06-06 00:01:00           75
# 2017-06-06 00:01:30           59
# 2017-06-06 00:02:00          157
# ...                          ...
# 2017-07-10 17:17:30           48
# 2017-07-10 17:18:00          198
# 2017-07-10 17:18:30           10
# 2017-07-10 17:19:00          103
# 2017-07-10 17:19:30           62
#
# [100000 rows x 1 columns]

# %%
df.resample('W').sum()
# Out:
#             sale_amount
# 2017-06-11      1736917
# 2017-06-18      2010727
# 2017-06-25      2035581
# 2017-07-02      2017421
# 2017-07-09      1998257
# 2017-07-16       209337

# %%
df.resample('2W').mean()
# Out:
#             sale_amount
# 2017-06-11   100.516030
# 2017-06-25   100.354861
# 2017-07-09    99.595188
# 2017-07-23   100.642788

# %% [markdown]
# # 3.15 Looping Over a Column

# %%
tdf = pd.read_csv(titanic_data_set_url)

# %%
for name in tdf['Name'][:2]:
    print(name.upper())
# Out:
# ALLEN, MISS ELISABETH WALTON
# ALLISON, MISS HELEN LORAINE

# %% [markdown]
# # 3.16 Applying a Function Over All Elements in a Column

# %%
def make_uppercase(x):
    return x.upper()

# %%
tdf['Name'].apply(make_uppercase)
# Out:
# 0                        ALLEN, MISS ELISABETH WALTON
# 1                         ALLISON, MISS HELEN LORAINE
# 2                 ALLISON, MR HUDSON JOSHUA CREIGHTON
# 3       ALLISON, MRS HUDSON JC (BESSIE WALDO DANIELS)
# 4                       ALLISON, MASTER HUDSON TREVOR
#                             ...
# 1308                               ZAKARIAN, MR ARTUN
# 1309                           ZAKARIAN, MR MAPRIEDER
# 1310                                 ZENNI, MR PHILIP
# 1311                                 LIEVENS, MR RENE
# 1312                                   ZIMMERMAN, LEO
# Name: Name, Length: 1313, dtype: str

# %% [markdown]
# # 3.17 Applying a Function to Groups

# %%
tdf.groupby('Sex').apply(lambda x: x.count())
# Out:
#         Name  PClass  Age  Survived  SexCode
# Sex
# female   462     462  288       462      462
# male     851     851  468       851      851

# %% [markdown]
# # 3.18 Concatenating DataFrames

# %%
data_a = {'id': ['1', '2', '3'],
 'first': ['Alex', 'Amy', 'Allen'],
 'last': ['Anderson', 'Ackerman', 'Ali']}
dataframe_a = pd.DataFrame(data_a, columns = ['id', 'first', 'last'])

# Create DataFrame
data_b = {'id': ['4', '5', '6'],
 'first': ['Billy', 'Brian', 'Bran'],
 'last': ['Bonder', 'Black', 'Balwner']}

dataframe_b = pd.DataFrame(data_b, columns = ['id', 'first', 'last'])


# Concatenate DataFrames by rows
pd.concat([dataframe_a, dataframe_b], axis=0)
# Out:
#   id  first      last
# 0  1   Alex  Anderson
# 1  2    Amy  Ackerman
# 2  3  Allen       Ali
# 0  4  Billy    Bonder
# 1  5  Brian     Black
# 2  6   Bran   Balwner

# %% [markdown]
# # 3.19 Merging DataFrames

# %%
employee_data = {'employee_id': ['1', '2', '3', '4'],
 'name': ['Amy Jones', 'Allen Keys', 'Alice Bees',
 'Tim Horton']}


dataframe_employees = pd.DataFrame(employee_data, columns = ['employee_id',
 'name'])

dataframe_employees
# Out:
#   employee_id        name
# 0           1   Amy Jones
# 1           2  Allen Keys
# 2           3  Alice Bees
# 3           4  Tim Horton

# %%
# Create DataFrame
sales_data = {'employee_id': ['3', '4', '5', '6'],
 'total_sales': [23456, 2512, 2345, 1455]}

dataframe_sales = pd.DataFrame(sales_data, columns = ['employee_id',
 'total_sales'])

dataframe_sales
# Out:
#   employee_id  total_sales
# 0           3        23456
# 1           4         2512
# 2           5         2345
# 3           6         1455

# %%
# Merge DataFrames
pd.merge(dataframe_employees, dataframe_sales, on='employee_id')
# Out:
#   employee_id        name  total_sales
# 0           3  Alice Bees        23456
# 1           4  Tim Horton         2512

# %%
pd.merge(
    dataframe_employees,
    dataframe_sales,
    on='employee_id',
    how='outer'
)
# Out:
#   employee_id        name  total_sales
# 0           1   Amy Jones          NaN
# 1           2  Allen Keys          NaN
# 2           3  Alice Bees      23456.0
# 3           4  Tim Horton       2512.0
# 4           5         NaN       2345.0
# 5           6         NaN       1455.0

# %%
pd.merge(dataframe_employees,
 dataframe_sales,
 left_on='employee_id',
 right_on='employee_id')
# Out:
#   employee_id        name  total_sales
# 0           3  Alice Bees        23456
# 1           4  Tim Horton         2512
