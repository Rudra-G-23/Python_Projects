# %%
5+5
# Out:
# 10

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as ms

# %%
path = r"C:\Users\Rudra\Desktop\kaggle\e-challen\data\echallan_daily_data.csv"

# %%
pd.read_csv(path)
# Out:
#             date  totalChallan  disposedChallan  pendingChallan  \
# 0     2015-01-01           120               29              91
# 1     2015-01-02           162               39             123
# 2     2015-01-03           122               34              88
# 3     2015-01-04           116               27              89
# 4     2015-01-05           162               28             134
# ...          ...           ...              ...             ...
# 4056  2026-02-09        242251            33045          209206
# 4057  2026-02-10        235459            30908          204551
# 4058  2026-02-11        234315            31543          202772
# 4059  2026-02-12        185594            24278          161316
# 4060  2026-02-13          5990               81            5909
#
#       pendingAmount  disposedAmount  totalAmount  pendingCourt  disposedCourt  \
# 0            588600          116860       705460             1              0
# ...
