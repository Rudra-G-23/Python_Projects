# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; font-size: 72px; background-color: #5a189a; color: #ffffff; padding: 20px; border-radius: 20px; text-align: center; box-shadow: 0 4px 10px rgba(0, 0, 0, 0.2);">
#     About the Author
# </div>
#
# <div style="padding: 40px; max-width: 1000px; margin: 40px auto; background-color: #f9f9f9; border-radius: 15px; box-shadow: 0 4px 20px rgba(0, 0, 0, 0.1);">
#     <p style="font-size: 130%; line-height: 1.8; color: #444;">
#         Hello, Data Enthusiasts! 👋<br>
#         I'm <b style="color: #4682B4;">Rudra Prasad Bhuyan</b>, a passionate Data Analyst on a mission to master the art of transforming raw data into valuable insights that drive decision-making and foster business growth.
#     </p>
# </div>
#
# <div style="text-align: center; padding: 20px; margin-top: 30px;">
#     <p style="font-size: 120%; color: #444; line-height: 1.6;">
#         Let’s connect and create amazing things together! <br>
#         Reach out to me on
#         <a href="https://www.linkedin.com/in/rudra-prasad-bhuyan-44a388235/" target="_blank" style="color: #0073b1; font-weight: bold; text-decoration: none;">LinkedIn</a>,
#         check out my projects on
#         <a href="https://github.com/Rudra-G-23" target="_blank" style="color: #000; font-weight: bold; text-decoration: none;">GitHub</a>,
#         or email me at
#         <a href="mailto:rudraprasadbhuyan999@gmail.com" style="color: #D44638; font-weight: bold; text-decoration: none;">rudraprasadbhuyan999@gmail.com</a>. <br>
#         I'm always excited to explore new opportunities, collaborate, or discuss all things data! 🧑‍💻😄
#     </p>
# </div>

# %% [markdown]
# <div style="font-family: Arial, sans-serif; font-size: 69px; background-color: #5a189a; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px; text-align: center;">Table of Content </div>

# %% [markdown]
# # Table of Contents
# 1. [📊 Understand the Data](#understand-the-data)
# 2. [🧹 Data Cleaning](#data-cleaning)
#    1. [Best practice](#best-practice)
# 3. [🔍 Analysis](#analysis)
#    1. [Correlation  Matrix ](#31)
#    2. [Daily Mobile Screen time ](#32)
#    3. [Count of Apps Used by Age](#33)
#    4. [App usages hours](#34)
#    5. [Mobile usages of Different age](#35)
#    6. [Distribution of App Usage Hours by Type](#36)
#    7. [](#37)
#    8. [](#38)
#    9. [](#39)
#    10. [](#310)
#    11. [](#311)
#    12. [](#312)
# 4. [📈 Conclusion](#conclusion)

# %% [markdown]
# <a id="understand-the-data"></a>
# <div style="background-color: #48cae4; border-radius: 15px; padding: 20px; text-align: left;">
#     <h1 style="margin: 0;">
#         <b>
#             <span style="color: Black;">Chapter One</span>
#             <span style="color: #ffffff;">|</span>
#             <span style="color: #FEEC37;"> Understand the Data 📊
#             </span>
#         </b>
#     </h1>
#     <br>
#     <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
#     </a>
# </div>

# %% [markdown]
# <a  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
# ⭐ install all libraries
# <a>

# %%
'''
# !pip install numpy pandas matplotlib seaborn plotly missingno dtable autoviz skimpy
'''
# Out:
# '\n!pip install numpy pandas matplotlib seaborn plotly missingno dtable autoviz\n'

# %%
# import  Basic libraries 
import os
import datetime as dt

# import necessary data wrangling libraries 
import numpy as np  
import pandas as pd

# import fundamental libraries of viz
import matplotlib.pyplot as plt
import seaborn as sns

# import advance libraries for dynamic graphs
import plotly.express as px  
import plotly.graph_objects as go  
import plotly.figure_factory as ff
from plotly.subplots import make_subplots

# import some extra libraries for fast and advance analysis 
import missingno as msno
from skimpy import skim
import dtable 

# Remove warnings 
import warnings
warnings.filterwarnings('ignore')

# %%
source = r'C:\Users\Rudra\Downloads\Python_Pandas_profiling\21321\mobile_usage_behavioral_analysis.csv'
df = pd.read_csv(source, encoding= 'unicode_escape')
df.sample(7)
# Out:
#      User_ID  Age  Gender  Total_App_Usage_Hours  Daily_Screen_Time_Hours  \
# 282      283   24    Male                   4.97                     9.86
# 743      744   19  Female                   9.06                     4.21
# 177      178   29  Female                  10.51                     8.08
# 656      657   28  Female                   8.73                     5.95
# 133      134   21    Male                  10.51                     8.28
# 88        89   28  Female                  10.20                     2.10
# 174      175   49  Female                   1.19                     9.81
#
#      Number_of_Apps_Used  Social_Media_Usage_Hours  \
# 282                   25                      1.20
# 743                    5                      2.50
# 177                   16                      1.05
# 656                   23                      0.86
# 133                   20                      4.48
# 88                    29                      1.38
# 174                   17                      4.45
#
#      Productivity_App_Usage_Hours  Gaming_App_Usage_Hours     Location
# 282                          1.05                    2.04      Houston
# 743                          1.71                    3.46      Phoenix
# 177                          4.61                    1.67     New York
# 656                          0.53                    0.94      Phoenix
# 133                          1.61                    2.73  Los Angeles
# 88                           2.63                    4.03      Chicago
# 174                          2.79                    4.23      Chicago

# %%
print("The size of the DataFrame:",df.size, '\n')
print('The Shape of the DataFrame', df.shape, '\n')
print("Available columns in the DataFrame:", df.columns)

# Calculate memory usage of the DataFrame
memory_size = df.memory_usage(deep=True).sum()
memory_size_mb = memory_size / (1024 ** 2)
print(f"\nEstimated memory size: {memory_size_mb:.2f} MB")
# Out:
# The size of the DataFrame: 10000
#
# The Shape of the DataFrame (1000, 10)
#
# Available columns in the DataFrame: Index(['User_ID', 'Age', 'Gender', 'Total_App_Usage_Hours',
#        'Daily_Screen_Time_Hours', 'Number_of_Apps_Used',
#        'Social_Media_Usage_Hours', 'Productivity_App_Usage_Hours',
#        'Gaming_App_Usage_Hours', 'Location'],
#       dtype='object')
#
# Estimated memory size: 0.17 MB

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   User_ID                       1000 non-null   int64
#  1   Age                           1000 non-null   int64
#  2   Gender                        1000 non-null   object
#  3   Total_App_Usage_Hours         1000 non-null   float64
#  4   Daily_Screen_Time_Hours       1000 non-null   float64
#  5   Number_of_Apps_Used           1000 non-null   int64
#  6   Social_Media_Usage_Hours      1000 non-null   float64
#  7   Productivity_App_Usage_Hours  1000 non-null   float64
#  8   Gaming_App_Usage_Hours        1000 non-null   float64
#  9   Location                      1000 non-null   object
# dtypes: float64(5), int64(3), object(2)
# memory usage: 78.3+ KB

# %%
df.describe(include='all').T
# Out:
#                                count unique       top freq     mean  \
# User_ID                       1000.0    NaN       NaN  NaN    500.5
# Age                           1000.0    NaN       NaN  NaN   38.745
# Gender                          1000      2      Male  517      NaN
# Total_App_Usage_Hours         1000.0    NaN       NaN  NaN  6.40567
# Daily_Screen_Time_Hours       1000.0    NaN       NaN  NaN  7.69631
# Number_of_Apps_Used           1000.0    NaN       NaN  NaN   16.647
# Social_Media_Usage_Hours      1000.0    NaN       NaN  NaN  2.45633
# Productivity_App_Usage_Hours  1000.0    NaN       NaN  NaN  2.49527
# Gaming_App_Usage_Hours        1000.0    NaN       NaN  NaN  2.47541
# Location                        1000      5  New York  243      NaN
#
#                                      std   min     25%    50%     75%     max
# User_ID                       288.819436   1.0  250.75  500.5  750.25  1000.0
# Age                            12.186734  18.0    28.0   40.0    50.0    59.0
# Gender                               NaN   NaN     NaN    NaN     NaN     NaN
# Total_App_Usage_Hours           3.134855   1.0    3.59  6.455  9.1225   11.97
# Daily_Screen_Time_Hours         3.714187  1.01    4.53   7.88   10.91    14.0
# Number_of_Apps_Used              7.61961   3.0    10.0   17.0    23.0    29.0
# Social_Media_Usage_Hours        1.439525   0.0     1.2  2.445  3.6725    4.99
# Productivity_App_Usage_Hours    1.443392   0.0  1.2825  2.435    3.71     5.0
# Gaming_App_Usage_Hours          1.450362  0.01    1.22  2.455  3.7825     5.0
# Location                             NaN   NaN     NaN    NaN     NaN     NaN

# %% [markdown]
# <a id="data-cleaning"></a>
# <div style="background-color: #48cae4; border-radius: 15px; padding: 20px; text-align: left;">
#     <h1 style="margin: 0;">
#         <b>
#             <span style="color: Black;">Chapter Two</span>
#             <span style="color: #ffffff;">|</span>
#             <span style="color: #FEEC37;"> Data Cleaning 🧹
#             </span>
#         </b>
#     </h1>
#     <br>
#     <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
#     </a>
# </div>

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# User_ID                         0
# Age                             0
# Gender                          0
# Total_App_Usage_Hours           0
# Daily_Screen_Time_Hours         0
# Number_of_Apps_Used             0
# Social_Media_Usage_Hours        0
# Productivity_App_Usage_Hours    0
# Gaming_App_Usage_Hours          0
# Location                        0
# dtype: int64

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# <a id="best-practice"></a>
# <div style="background-color: #48cae4; border-radius: 15px; padding: 20px; text-align: left;">
# <p style="color: Black;">
#    ⭐ <b>Best Practices <b>
#    <pre  style="color: Black; font-size: 20px;">
#    1.Before clean the data have a copy of Original Data.
#
#    </pre>
# </p>
#     <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
#     </a>
# </div>

# %%
dfc = df.copy()

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">⭐ More details and fast Analysis use dtable libraries </div>

# %%
d = dtale.show(df)
print(d._url)  # Print the URL to manually open in the browser
# Out:
# http://LAPTOP-E03IAI0P:40000

# %%
# Launch D-Tale
'''
import dtable 
d = dtale.show(df)
print(d._url)  # Print the URL to manually open in the browser
'''
# Out:
# '\nimport dtable \nd = dtale.show(df)\nd.open_browser()  # Open the visualization in your default browser\n'

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">⭐Ato generate the graph for more fast & speed up Analysis </div>

# %%
from autoviz.AutoViz_Class import AutoViz_Class

AV = AutoViz_Class()

df_auto = AV.AutoViz(
    filename='', 
    dfte=df, 
    depVar='', 
    chart_format='png', 
    verbose=2
)
# Out:
# Shape of your Data Set loaded: (1000, 10)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#   Printing up to 30 columns (max) in each category:
#     Numeric Columns : ['Total_App_Usage_Hours', 'Daily_Screen_Time_Hours', 'Social_Media_Usage_Hours', 'Productivity_App_Usage_Hours', 'Gaming_App_Usage_Hours']
#     Integer-Categorical Columns: ['Age', 'Number_of_Apps_Used']
#     String-Categorical Columns: ['Location']
#     Factor-Categorical Columns: []
#     String-Boolean Columns: ['Gender']
#     Numeric-Boolean Columns: []
#     Discrete String Columns: []
#     NLP text Columns: []
#     Date Time Columns: []
#     ID Columns: ['User_ID']
#     Columns that will not be considered in modeling: []
#     10 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['User_ID']
#    Columns to delete:
# '   []'
#    Boolean variables %s
# "   ['Gender']"
#    Categorical variables %s
# "   ['Location', 'Age', 'Number_of_Apps_Used', 'Gender']"
#    Continuous variables %s
# ("   ['Total_App_Usage_Hours', 'Daily_Screen_Time_Hours', "
#  "'Social_Media_Usage_Hours', 'Productivity_App_Usage_Hours', "
#  "'Gaming_App_Usage_Hours']")
#    Discrete string variables %s
# '   []'
#    Date and time variables %s
# '   []'
#    ID variables %s
# "   ['User_ID']"
#    Target variable %s
# '   '
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_8d776_row0_col0, #T_8d776_row0_col2, #T_8d776_row0_col3, #T_8d776_row0_col4, #T_8d776_row0_col5, #T_8d776_row1_col0, #T_8d776_row1_col2, #T_8d776_row1_col3, #T_8d776_row1_col4, #T_8d776_row1_col5, #T_8d776_row2_col0, #T_8d776_row2_col2, #T_8d776_row2_col3, #T_8d776_row2_col4, #T_8d776_row2_col5, #T_8d776_row3_col0, #T_8d776_row3_col2, #T_8d776_row3_col3, #T_8d776_row3_col4, #T_8d776_row3_col5, #T_8d776_row4_col0, #T_8d776_row4_col2, #T_8d776_row4_col3, #T_8d776_row4_col4, #T_8d776_row4_col5, #T_8d776_row5_col0, #T_8d776_row5_col2, #T_8d776_row5_col3, #T_8d776_row5_col4, #T_8d776_row5_col5, #T_8d776_row6_col0, #T_8d776_row6_col2, #T_8d776_row6_col3, #T_8d776_row6_col4, #T_8d776_row6_col5, #T_8d776_row7_col0, #T_8d776_row7_col2, #T_8d776_row7_col3, #T_8d776_row7_col4, #T_8d776_row7_col5, #T_8d776_row8_col0, #T_8d776_row8_col2, #T_8d776_row8_col3, #T_8d776_row8_col4, #T_8d776_row8_col5, #T_8d776_row9_col0, #T_8d776_row9_col2, #T_8d776_row9_col3, #T_8d776_row9_col4, #T_8d776_row9_col5 {
#   font-family: Segoe UI;
# }
# #T_8d776_row0_col1, #T_8d776_row1_col1, #T_8d776_row2_col1, #T_8d776_row3_col1, #T_8d776_row4_col1, #T_8d776_row5_col1, #T_8d776_row6_col1, #T_8d776_row7_col1, #T_8d776_row8_col1, #T_8d776_row9_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_8d776">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d776_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_8d776_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_8d776_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_8d776_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_8d776_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_8d776_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d776_level0_row0" class="row_heading level0 row0" >User_ID</th>
#       <td id="T_8d776_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_8d776_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_8d776_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_8d776_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_8d776_row0_col4" class="data row0 col4" >1000.000000</td>
#       <td id="T_8d776_row0_col5" class="data row0 col5" >Possible ID column: drop before modeling step.</td>
#     </tr>
#     <tr>
#       <th id="T_8d776_level0_row1" class="row_heading level0 row1" >Age</th>
#       <td id="T_8d776_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_8d776_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_8d776_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_8d776_row1_col3" class="data row1 col3" >18.000000</td>
#       <td id="T_8d776_row1_col4" class="data row1 col4" >59.000000</td>
#       <td id="T_8d776_row1_col5" class="data row1 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_8d776_level0_row2" class="row_heading level0 row2" >Gender</th>
#       <td id="T_8d776_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_8d776_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_8d776_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_8d776_row2_col3" class="data row2 col3" ></td>
#       <td id="T_8d776_row2_col4" class="data row2 col4" ></td>
#       <td id="T_8d776_row2_col5" class="data row2 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_8d776_level0_row3" class="row_heading level0 row3" >Total_App_Usage_Hours</th>
#       <td id="T_8d776_row3_col0" class="data row3 col0" >float64</td>
#       <td id="T_8d776_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_8d776_row3_col2" class="data row3 col2" >NA</td>
#       <td id="T_8d776_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_8d776_row3_col4" class="data row3 col4" >11.970000</td>
#       <td id="T_8d776_row3_col5" class="data row3 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_8d776_level0_row4" class="row_heading level0 row4" >Daily_Screen_Time_Hours</th>
#       <td id="T_8d776_row4_col0" class="data row4 col0" >float64</td>
#       <td id="T_8d776_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_8d776_row4_col2" class="data row4 col2" >NA</td>
#       <td id="T_8d776_row4_col3" class="data row4 col3" >1.010000</td>
#       <td id="T_8d776_row4_col4" class="data row4 col4" >14.000000</td>
#       <td id="T_8d776_row4_col5" class="data row4 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_8d776_level0_row5" class="row_heading level0 row5" >Number_of_Apps_Used</th>
#       <td id="T_8d776_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_8d776_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_8d776_row5_col2" class="data row5 col2" >2</td>
#       <td id="T_8d776_row5_col3" class="data row5 col3" >3.000000</td>
#       <td id="T_8d776_row5_col4" class="data row5 col4" >29.000000</td>
#       <td id="T_8d776_row5_col5" class="data row5 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_8d776_level0_row6" class="row_heading level0 row6" >Social_Media_Usage_Hours</th>
#       <td id="T_8d776_row6_col0" class="data row6 col0" >float64</td>
#       <td id="T_8d776_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_8d776_row6_col2" class="data row6 col2" >NA</td>
#       <td id="T_8d776_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_8d776_row6_col4" class="data row6 col4" >4.990000</td>
#       <td id="T_8d776_row6_col5" class="data row6 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_8d776_level0_row7" class="row_heading level0 row7" >Productivity_App_Usage_Hours</th>
#       <td id="T_8d776_row7_col0" class="data row7 col0" >float64</td>
#       <td id="T_8d776_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_8d776_row7_col2" class="data row7 col2" >NA</td>
#       <td id="T_8d776_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_8d776_row7_col4" class="data row7 col4" >5.000000</td>
#       <td id="T_8d776_row7_col5" class="data row7 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_8d776_level0_row8" class="row_heading level0 row8" >Gaming_App_Usage_Hours</th>
#       <td id="T_8d776_row8_col0" class="data row8 col0" >float64</td>
#       <td id="T_8d776_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_8d776_row8_col2" class="data row8 col2" >NA</td>
#       <td id="T_8d776_row8_col3" class="data row8 col3" >0.010000</td>
#       <td id="T_8d776_row8_col4" class="data row8 col4" >5.000000</td>
#       <td id="T_8d776_row8_col5" class="data row8 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_8d776_level0_row9" class="row_heading level0 row9" >Location</th>
#       <td id="T_8d776_row9_col0" class="data row9 col0" >object</td>
#       <td id="T_8d776_row9_col1" class="data row9 col1" >0.000000</td>
#       <td id="T_8d776_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_8d776_row9_col3" class="data row9 col3" ></td>
#       <td id="T_8d776_row9_col4" class="data row9 col4" ></td>
#       <td id="T_8d776_row9_col5" class="data row9 col5" >No issue</td>
#     </tr>
#   </tbody>
# </table>
# Number of All Scatter Plots = 15
# All Plots are saved in .\AutoViz_Plots\AutoViz
# Time to run AutoViz = 8 seconds

# %% [markdown]
# <a id="analysis"></a>
# <div style="background-color: #48cae4; border-radius: 15px; padding: 20px; text-align: left;">
#     <h1 style="margin: 0;">
#         <b>
#             <span style="color: Black;">Chapter Three</span>
#             <span style="color: #ffffff;">|</span>
#             <span style="color: #FEEC37;"> Analysis 🔍
#             </span>
#         </b>
#     </h1>
#     <br>
#     <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
#     </a>
# </div>

# %% [markdown]
# <a id="31"></a>
# ### <div style="text-align:left; border-radius:15px; padding:20px; color:#000000; margin:0; font-size:100%; font-family:Arial, sans-serif; background-color:#48cae4; overflow:hidden;"><b>⚡ 1. Correlation Matrix</b>
#
# <a href="#table-of-contents" style="font-family:Arial, sans-serif; font-size:15px; background-color:#7b2cbf; color:#ffffff; padding:7px 15px; text-decoration:none; border-radius:15px; margin-left:10px;">
#     [Table of Content 📜⬆️]
# </a>
# </div>

# %%
numeric_df = df.select_dtypes(include=[float, int])
correlation_matrix = numeric_df.corr().T

fig = px.imshow(correlation_matrix, text_auto=True, aspect="auto",
                title='Correlation Matrix',
                color_continuous_scale='viridis')
fig.show()

# %%
# Get a skim summary of the dataset
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 1000   │ │ float64     │ 5     │                                                          │
# │ │ Number of columns │ 10     │ │ int32       │ 3     │                                                          │
# │ └───────────────────┴────────┘ │ string      │ 2     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━┳━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━┓  │
# │ ┃ column_name             ┃ NA  ┃ NA %  ┃ mean   ┃ sd     ┃ p0    ┃ p25    ┃ p50    ┃ p75   ┃ p100  ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━╇━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━┩  │
# │ │ User_ID                 │   0 │     0 │  500.5 │  288.8 │     1 │  250.8 │  500.5 │ 750.2 │  1000 │ ▇▇▇▇▇▇ │  │
# │ │ Age                     │   0 │     0 │  38.74 │  12.19 │    18 │     28 │     40 │    50 │    59 │ ▇▇▆▇▇▇ │  │
# │ │ Total_App_Usage_Hours   │   0 │     0 │  6.406 │  3.135 │     1 │   3.59 │  6.455 │ 9.122 │ 11.97 │ ▇▇▇▇▇▆ │  │
# │ │ Daily_Screen_Time_Hours │   0 │     0 │  7.696 │  3.714 │  1.01 │   4.53 │   7.88 │ 10.91 │    14 │ ▇▆▇▇▇▇ │  │
# │ │ Number_of_Apps_Used     │   0 │     0 │  16.65 │   7.62 │     3 │     10 │     17 │    23 │    29 │ ▆▆▆▇▆▇ │  │
# │ │ Social_Media_Usage_Hour │   0 │     0 │  2.456 │   1.44 │     0 │    1.2 │  2.445 │ 3.672 │  4.99 │ ▇▇▇▇▇▇ │  │
# │ │ s                       │     │       │        │        │       │        │        │       │       │        │  │
# │ │ Productivity_App_Usage_ │   0 │     0 │  2.495 │  1.443 │     0 │  1.282 │  2.435 │  3.71 │     5 │ ▇▇▇▇▇▇ │  │
# │ │ Hours                   │     │       │        │        │       │        │        │       │       │        │  │
# │ │ Gaming_App_Usage_Hours  │   0 │     0 │  2.475 │   1.45 │  0.01 │   1.22 │  2.455 │ 3.782 │     5 │ ▇▇▇▇▇▇ │  │
# │ └─────────────────────────┴─────┴───────┴────────┴────────┴───────┴────────┴────────┴───────┴───────┴────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name               ┃ NA      ┃ NA %       ┃ words per row                ┃ total words              ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ Gender                    │       0 │          0 │                            1 │                     1000 │  │
# │ │ Location                  │       0 │          0 │                          1.4 │                     1428 │  │
# │ └───────────────────────────┴─────────┴────────────┴──────────────────────────────┴──────────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
# ⭐
#
# </div>

# %% [markdown]
# <a id="32"></a>
# ### <div style="text-align:left; border-radius:15px; padding:20px; color:Black; margin:0; font-size:100%; font-family:Arial; background-color:#48cae4; overflow:hidden"><b>⚡ 2. Daily Mobile Screen time </b>
# <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 15px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
# </a>
# </div>

# %%
fig = px.scatter(
    df,
    x='Age',  
    y='Daily_Screen_Time_Hours', 
    color='Gender', 
    size='Daily_Screen_Time_Hours', 
    symbol='Location',  # Column name as string
    opacity=0.8,
    size_max=15,  
    marginal_x='histogram',  
    marginal_y='box',  
    trendline='lowess', 
    height=800,
    width=2000,
    title='<b>Daily Mobile Screen time </b>'
    
)


fig.show()

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
# ⭐
#
# </div>

# %% [markdown]
# <a id="33"></a>
# ### <div style="text-align:left; border-radius:15px; padding:20px; color:Black; margin:0; font-size:100%; font-family:Arial; background-color:#48cae4; overflow:hidden"><b>⚡ 3. Count of Apps Used by Age </b>
# <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 15px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
# </a>
# </div>

# %%
px.hi

# %%
import plotly.express as px

# Bar chart to evaluate count of Number_of_Apps_Used per Age
fig = px.histogram(
    df, 
    x='Age', 
    y='Number_of_Apps_Used', 
    histfunc='count',  
)

fig.update_layout(
    bargap=0.2,
    title="Count of Apps Used by Age")

fig.show()

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
# ⭐
#
# </div>

# %% [markdown]
# <a id="34"></a>
# ### <div style="text-align:left; border-radius:15px; padding:20px; color:Black; margin:0; font-size:100%; font-family:Arial; background-color:#48cae4; overflow:hidden"><b>⚡4. App usages Hours  </b>
# <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 15px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
# </a>
# </div>

# %%
work_type_df = df.melt(
    id_vars=['Age', 'Gender'],
    value_vars=['Social_Media_Usage_Hours', 'Productivity_App_Usage_Hours', 'Gaming_App_Usage_Hours'],
    var_name='App_Usage_Type',
    value_name='Usage_Hours',
)

work_type_df.sample(3)
# Out:
#       Age  Gender         App_Usage_Type         Usage_Hours
# 892   20   Female      Social_Media_Usage_Hours     0.00
# 2689  21     Male        Gaming_App_Usage_Hours     4.41
# 1805  55   Female  Productivity_App_Usage_Hours     3.23

# %%
fig = px.histogram(
    work_type_df,
    x='Usage_Hours',
    color='App_Usage_Type',
    barmode='group',
    
)

fig.update_layout(
    title='App usages Hours ',
    bargap=0.3
)

fig.show()

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
# ⭐
#
# </div>

# %% [markdown]
# <a id="35"></a>
# ### <div style="text-align:left; border-radius:15px; padding:20px; color:Black; margin:0; font-size:100%; font-family:Arial; background-color:#48cae4; overflow:hidden"><b>⚡ 5. Mobile usages of Different age</b>
# <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 15px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
# </a>
# </div>

# %%
fig = px.histogram(
    work_type_df,
    x='Age',
    y='Usage_Hours',
    color='App_Usage_Type',
    barmode='group',
    #pattern_shape='Gender',
    facet_row='Gender',
    
)

fig.update_layout(
    title=' Mobile usages of Different age',
    bargap=0.3,
    height=600,
    width=1800,
)

fig.show()

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
# ⭐
#
# </div>

# %% [markdown]
# <a id="36"></a>
# ### <div style="text-align:left; border-radius:15px; padding:20px; color:Black; margin:0; font-size:100%; font-family:Arial; background-color:#48cae4; overflow:hidden"><b>⚡ 6. Distribution of App Usage Hours by Type</b>
# <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 15px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
# </a>
# </div>

# %%
app_usage_summary = work_type_df.groupby('App_Usage_Type')['Usage_Hours'].sum().reset_index
app_usage_summary
# Out:
# <bound method Series.reset_index of App_Usage_Type
# Gaming_App_Usage_Hours          2475.41
# Productivity_App_Usage_Hours    2495.27
# Social_Media_Usage_Hours        2456.33
# Name: Usage_Hours, dtype: float64>

# %%
fig = px.pie(
    app_usage_summary,
    names='App_Usage_Type',       
    values='Usage_Hours',        
    title="Distribution of App Usage Hours by Type"
)

fig.show()

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
# ⭐
#
# </div>

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; font-size: 72px; background-color: #5a189a; color: #ffffff; padding: 20px; border-radius: 20px; text-align: center; box-shadow: 0 4px 10px rgba(0, 0, 0, 0.2);">
# 🌟 Thank you 🌟
# </div>
